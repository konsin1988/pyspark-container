# %%
from pyspark.sql.functions import col
import pyspark.sql.functions as F
import pyspark.sql.types as T

from pyspark.ml import Pipeline, Transformer
from pyspark.ml.feature import VectorAssembler, StandardScaler, Imputer, OneHotEncoder, StringIndexer
from pyspark.ml.classification import GBTClassifier

# from sklearn.model_selection import train_test_split, cross_val_score
# from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

import optuna

# from giskard import Dataset, Model, scan, testing
import pickle

import warnings

import clickhouse_connect
import psycopg2

from functools import reduce

import clickhouse_connect

import mlflow 
import mlflow.catboost
import mlflow.sklearn
import mlflow.data
from mlflow.models import infer_signature

from datetime import datetime

# %% [markdown]
# # Load env variables

# %%
from dotenv import load_dotenv
import os

load_dotenv()

SPARK_COMPAT_VERSION = os.getenv('SPARK_COMPAT_VERSION')
SCALA_COMPAT_VERSION = os.getenv('SCALA_COMPAT_VERSION')
CATBOOST_SPARK_VERSION = os.getenv('CATBOOST_SPARK_VERSION')
CLICKHOUSE_HOST = os.getenv('CLICKHOUSE_HOST')
CLICKHOUSE_PORT = os.getenv('CLICKHOUSE_PORT')
CLICKHOUSE_USER = os.getenv('CLICKHOUSE_USER')
CLICKHOUSE_PASSWORD = os.getenv('CLICKHOUSE_PASSWORD')

ACCESS_KEY=os.getenv('MINIO_ROOT_USER')
SECRET_KEY=os.getenv('MINIO_ROOT_PASSWORD')

# %% [markdown]
# # Get spark client, connect to clickhouse

# %%
from pyspark.sql import SparkSession

packages = [
    "com.clickhouse.spark:clickhouse-spark-runtime-3.4_2.12:0.8.0",
    "com.clickhouse:clickhouse-client:0.7.0",
    "com.clickhouse:clickhouse-http-client:0.7.0",
    "org.apache.httpcomponents.client5:httpclient5:5.2.1",
    f"ai.catboost:catboost-spark_{SPARK_COMPAT_VERSION}_{SCALA_COMPAT_VERSION}:{CATBOOST_SPARK_VERSION}"
]

spark = (SparkSession
         .builder
         .config("spark.jars.packages", ",".join(packages))
         .master("local[1]")
         .getOrCreate())

spark.conf.set("spark.sql.catalog.clickhouse", "com.clickhouse.spark.ClickHouseCatalog")
spark.conf.set("spark.sql.catalog.clickhouse.host", f"{CLICKHOUSE_HOST}")
spark.conf.set("spark.sql.catalog.clickhouse.protocol", "http")
spark.conf.set("spark.sql.catalog.clickhouse.http_port", f"{CLICKHOUSE_PORT}")
spark.conf.set("spark.sql.catalog.clickhouse.user", f"{CLICKHOUSE_USER}")
spark.conf.set("spark.sql.catalog.clickhouse.password", f"{CLICKHOUSE_PASSWORD}")
spark.conf.set("spark.sql.catalog.clickhouse.database", "credit")
spark.conf.set("spark.clickhouse.write.format", "json")

sc = spark.sparkContext
rdd = sc.parallelize(range(100 + 1))

# %% [markdown]
# ### Import catboost_spark (only after spark packages loading)

# %%
import catboost_spark
from catboost_spark import CatBoostClassifier

# %% [markdown]
# # Set feature and target columns

# %%
COLUMN_TYPES = {
    'age': 'category',
    'sex': 'category',
    'job': 'category',
    'housing': 'category',
    'credit_amount': 'numeric',
    'duration': 'numeric'
}

TARGET_COLUMN_NAME = 'default'
FEATURE_COLUMNS = [i for i in COLUMN_TYPES.keys()]
FEATURE_TYPES = {i: COLUMN_TYPES[i] for i in COLUMN_TYPES if i != TARGET_COLUMN_NAME}

COLUMNS_TO_SCALE = [key for key in COLUMN_TYPES.keys() if COLUMN_TYPES[key] == "numeric"]
COLUMNS_TO_ENCODE = [key for key in COLUMN_TYPES.keys() if COLUMN_TYPES[key] == "category"]

# %% [markdown]
# # Get data

# %%
job_list = {
    0: 'unskilled and non-resident', 
    1: 'unskilled and resident', 
    2: 'skilled', 
    3: 'highly skilled'
}

# %%
query = 'select * from clickhouse.credit.credit'
x = spark.sql(query)
x.show()

# %%
X_query = f"SELECT {reduce(lambda a,b: a + ', ' + b, FEATURE_COLUMNS + [TARGET_COLUMN_NAME])} FROM clickhouse.credit.credit;"

str_job = F.udf(lambda x: job_list[x], T.StringType())
data = (
    spark
    .sql(X_query)
    .withColumn('job', str_job(col('job')))
)

# %% [markdown]
# # Pipeline

# %%
stages = []

# transform the dataset column that we want to predict into a spark row vector
label_stringIdx = StringIndexer(inputCol = 'default', outputCol = 'target', handleInvalid = 'keep')
stages += [label_stringIdx]

# transform string columns into spark categorical strings
for cat_col in COLUMNS_TO_ENCODE:
    imputer = Imputer(strategy='mode', inputCol=cat_col, outputCol=cat_col + 'Imp')
    stringIndexer = StringIndexer(inputCol = cat_col,
                                  outputCol = cat_col + 'Index',
                                  handleInvalid = 'keep')
    encoder = OneHotEncoder(inputCol=stringIndexer.getOutputCol(),
                            outputCol=cat_col)
    stages += [imputer, stringIndexer, encoder]

# transform numeric vars
for num_col in COLUMNS_TO_SCALE:
    imputer = Imputer(strategy='median', inputCol=num_col, outputCol=num_col + 'Imp')
    scaler = StandardScaler(inputCol=imputer.getOutputCol(), outputCol=num_col)
    stages += [imputer, scaler]

# assembler - multiple cols to one
assembler = VectorAssembler(inputCols=FEATURE_COLUMNS, outputCol="features")
stages += [assembler]

# %%
X_train, X_test = data.randomSplit([0.7, 0.3])

gbt = GBTClassifier(maxIter=5, maxDepth=2, labelCol="target", seed=42, leafCol="leafId", featuresCol='features')
stages += [gbt]

pipeline = Pipeline(stages=stages)

# %%
model = pipeline.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 model = pipeline.fit(X_train)
#
# File /usr/local/spark/python/pyspark/ml/base.py:205, in Estimator.fit(self, dataset, params)
#     203         return self.copy(params)._fit(dataset)
#     204     else:
# --> 205         return self._fit(dataset)
#     206 else:
#     207     raise TypeError(
#     208         "Params must be either a param map or a list/tuple of param maps, "
#     209         "but got %s." % type(params)
#     210     )
#
# File /usr/local/spark/python/pyspark/ml/pipeline.py:134, in Pipeline._fit(self, dataset)
#     132     dataset = stage.transform(dataset)
#     133 else:  # must be an Estimator
# --> 134     model = stage.fit(dataset)
#     135     transformers.append(model)
#     136     if i < indexOfLastEstimator:
#
# ...

# %% [markdown]
# # MLflow connection

# %%
warnings.filterwarnings('ignore')
mlflow.set_tracking_uri('http://localhost:5000/')
print("URI", mlflow.get_tracking_uri())
# Out:
# URI http://localhost:5000/

# %%
imputer = Imputer(strategy='median', inputCols=COLUMNS_TO_SCALE, outputCols=COLUMNS_TO_SCALE)
scaler = StandardScaler()
numeric_transformer = Pipeline(stages = [imputer, scaler])

categorical_transformer = Pipeline(stages = [
    ("imputer", Imputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handleInvalid="keep"))
])
# 
# preprocessor = Transformer(
#     transformers=[
#         ("num", numeric_transformer, COLUMNS_TO_SCALE),
#         ("cat", categorical_transformer, COLUMNS_TO_ENCODE)
#     ]
# )
# X_preproccessed = preprocessor.fit_transform(X)
